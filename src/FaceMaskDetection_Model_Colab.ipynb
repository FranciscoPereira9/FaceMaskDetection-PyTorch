# %% [markdown]
# # Face Mask Detection Model Using PyTorch
#
# This notebook was built on Google Colab.

# %%
# Include drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install --upgrade albumentations

# %% [markdown]
# ### Import Libraries

# %%
# Nedded Libraries

# PyTorch
import torch 
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor, fasterrcnn_resnet50_fpn
import albumentations as A

# Image processing
from PIL import Image, ImageDraw, ExifTags, ImageColor, ImageFont

# Image Plots
from matplotlib import pyplot as plt
import matplotlib.patches as patches

# Data managements
import numpy as np
import pandas as pd

# File interpretation
import os
import xml.etree.ElementTree as ET
import random

# Others
import time
from collections import Counter
from random import seed, randint
from datetime import datetime

# %% [markdown]
# ### Find Annotation Files
#
# Indicate the path for the annotation files.

# %%
# Annotations directory path
ann_directory = '/content/drive/MyDrive/FaceMaskDetection/annotations'

# List directory
ann_files = os.listdir(ann_directory)

# %% [markdown]
# ### Find Image Files
#
# Indicate the path for the image files.

# %%
# Image directory path
img_directory = '/content/drive/MyDrive/FaceMaskDetection/images'

# List directory
img_files = os.listdir(img_directory)

# %% [markdown]
# ### Helper Functions
#
# This are auxiliary functions used throughout the notebook. This way the notebook stays tidy and clean.

# %%
def draw_bounding_boxes(img_tensor, target=None, prediction=None):
    """Draws bounding boxes in given images. Displays them

        Inputs:
          img:
            Image in tensor format.
          target:
            target dictionary containing bboxes list wit format -> [xmin, ymin, xmax, ymax]

        Returns:
          None
        """

    img = torchvision.transforms.ToPILImage()(img_tensor)

    # fetching the dimensions
    wid, hgt = img.size
    print(str(wid) + "x" + str(hgt))

    # Img to draw in
    draw = ImageDraw.Draw(img)

    if target:
        target_bboxes = target['boxes'].numpy().tolist()
        target_labels = decode_labels(target['labels'].numpy())

        for i in range(len(target_bboxes)):
            # Create Rectangle patches and add the patches to the axes
            draw.rectangle(target_bboxes[i], fill=None, outline='green', width=1)
            draw.text(target_bboxes[i][:2], target_labels[i], fill='green', font=None, anchor=None, spacing=4,
                      align='left', direction=None, features=None, language=None, stroke_width=0, stroke_fill=None,
                      embedded_color=False)

    if prediction:
        prediction_bboxes = prediction['boxes'].detach().cpu().numpy().tolist()
        prediction_labels = decode_labels(prediction['labels'].detach().cpu().numpy())
        for i in range(len(prediction_bboxes)):
            # Create Rectangle patches and add the patches to the axes
            draw.rectangle(prediction_bboxes[i], fill=None, outline='red', width=1)
            draw.text(prediction_bboxes[i][:2], prediction_labels[i], fill='red', font=None, anchor=None, spacing=4,
                      align='left', direction=None, features=None, language=None, stroke_width=0, stroke_fill=None,
                      embedded_color=False)

    display(img)

# %%
def encoded_labels(lst_labels):
    """Encodes label classes from string to integers.

        Labels are encoded accordingly:
            - background => 0
            - with_mask => 1
            - mask_weared_incorrect => 2
            - without_mask => 3

            Args:
              lst_labels:
                A list with classes in string format (e.g. ['with_mask', 'mask_weared_incorrect'...]).

            Returns:
              encoded:
                A list with integers that represent each class.
            """

    encoded=[]
    for label in lst_labels:
        if label == "with_mask":
            code = 1
        elif label == "mask_weared_incorrect":
            code = 2
        elif label == "without_mask":
            code = 3
        else:
            code = 0
        encoded.append(code)
    return encoded

# %%
def decode_labels(lst_labels):
    """
    Decode label classes from integers to strings.
    Labels are encoded accordingly:
        - background => 0
        - with_mask => 1
        - mask_weared_incorrect => 2
        - without_mask => 3

    Args:
      lst_labels:
        A list with classes in integer format (e.g. [1, 2, ...]).

    Returns:
        A list with strings that represent each class.
    """

    labels=[]
    for code in lst_labels:
        if code == 1:
            label = "with_mask"
        elif code == 2:
            label = "mask_weared_incorrect"
        elif code == 3:
            label = "without_mask"
        else:
            label = 'background'
        labels.append(label)
    return labels

# %%
def build_model(nclasses):
    """
    Builds model. Uses Faster R-CNN pre-trained on COCO dataset.

    Args:
      nclasses:
        number of classes

    Return:
      model: Faster R-CNN pre-trained model
    """
    # load pre-trained model on COCO
    model = fasterrcnn_resnet50_fpn(pretrained=False)

    # get the number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features

    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, nclasses)

    return model

# %%
def train_model(model, loader, optimizer, scheduler, epochs, device):
  """ 
    Inputs:
      - model
      - loader: Dataloader PyTorch object with training data
      - optimizer
      - scheduler
      - epochs
      - device

    Returns:
      - model
      - loss_list: list with mean loss per epoch. Epoch 1 is in idex 0.
    """
  # Create a loss list to keep epoch average loss
  loss_list = []
  # Epochs
  for epoch in range(epochs):
      print('Starting epoch...... {}/{} '.format(epoch + 1, epochs))
      iteration = 0
      loss_sub_list = []
      start = time.time()
      for images, targets in loader:
          # Agregate images in batch loader
          images = list(image.to(device) for image in images)

          # Agregate targets in batch loader
          targets = [{key: val.to(device) for key, val in target.items()} for target in targets]

          # Sets model to train mode (just a flag)
          model.train()

          # Output of model returns loss and detections
          optimizer.zero_grad()
          output = model(images, targets)

          # Calculate Cost
          losses = sum(loss for loss in output.values())
          loss_value = losses.item()
          loss_sub_list.append(loss_value)
          print('')

          # Update optimizer and learning rate
          losses.backward()
          optimizer.step()
          iteration += 1
          print('Iteration: {:d} --> Loss: {:.3f}'.format(iteration, loss_value))
          
      end = time.time()
      # update scheduler
      scheduler.step()
      # print the loss of epoch
      epoch_loss = np.mean(loss_sub_list)
      loss_list.append(epoch_loss)
      print('Epoch loss: {:.3f} , time used: ({:.1f}s)'.format(epoch_loss, end - start))
      
  return model, loss_list

# %%
def apply_nms(orig_prediction, iou_thresh):
    """
    Applies non max supression and eliminates low score bounding boxes.

      Args:
        orig_prediction: the model output. A dictionary containing element scores and boxes.
        iou_thresh: Intersection over Union threshold. Every bbox prediction with an IoU greater than this value
                      gets deleted in NMS.

      Returns:
        final_prediction: Resulting prediction
    """

    # torchvision returns the indices of the bboxes to keep
    keep = torchvision.ops.nms(orig_prediction['boxes'], orig_prediction['scores'], iou_thresh)

    # Keep indices from nms
    final_prediction = orig_prediction
    final_prediction['boxes'] = final_prediction['boxes'][keep]
    final_prediction['scores'] = final_prediction['scores'][keep]
    final_prediction['labels'] = final_prediction['labels'][keep]

    return final_prediction

# %%
def remove_low_score_bb(orig_prediction, score_thresh):
    """
    Eliminates low score bounding boxes.

    Args:
        orig_prediction: the model output. A dictionary containing element scores and boxes.
        score_thresh: Boxes with a lower confidence score than this value get deleted

    Returns:
        final_prediction: Resulting prediction
    """

    # Remove low confidence scores according to given threshold
    index_list_scores = []
    scores = orig_prediction['scores'].detach().cpu().numpy()
    for i in range(len(scores)):
        if scores[i] > score_thresh:
            index_list_scores.append(i)
    keep = torch.tensor(index_list_scores)

    # Keep indices from high score bb
    final_prediction = orig_prediction
    final_prediction['boxes'] = final_prediction['boxes'][keep]
    final_prediction['scores'] = final_prediction['scores'][keep]
    final_prediction['labels'] = final_prediction['labels'][keep]

    return final_prediction

# %%
def collate_fn(batch):
    # Collate function for Dataloader
    return tuple(zip(*batch))

# %%
def IOU(box1, box2):
    '''
    Intersection over Union - IoU
    *------------
    |   (x2min,y2min)
    |   *----------
    |   | ######| |
    ----|------* (x1max,y1max)
        |         |
        ----------

    Args:
        box1: [xmin,ymin,xmax,ymax]
        box2: [xmin,ymin,xmax,ymax]

    Returns:
        iou -> value of intersection over union of the 2 boxes

    '''

    # Compute coordinates of intersection
    xmin_inter = max(box1[0], box2[0])
    ymin_inter = max(box1[1], box2[1])
    xmax_inter = min(box1[2], box2[2])
    ymax_inter = min(box1[3], box2[3])

    # calculate area of intersection rectangle
    inter_area = max(0, xmax_inter - xmin_inter + 1) * max(0, ymax_inter - ymin_inter + 1) # FIXME why plus one?
 
    # calculate boxes areas
    area1 = (box1[2] - box1[0] + 1) * (box1[3] - box1[1] + 1)
    area2 = (box2[2] - box2[0] + 1) * (box2[3] - box2[1] + 1)
 
    # compute IoU
    iou = inter_area / float(area1 + area2 - inter_area)
    assert iou >= 0
    return iou

# %%
def compute_AP(ground_truth, predictions, iou_thresh=0.5, n_classes=4):
    """
    Calculates Average Precision across all classes.

    Args:
        ground_truth: list with ground-truth objects. Needs to have the following format: [sequence, frame, obj, [xmin, ymin, xmax, ymax], label, score]
        predictions: list with predictions objects. Needs to have the following format: [sequence, frame, obj, [xmin, ymin, xmax, ymax], label, score]
        iou_thresh: IoU to which a prediction compared to a ground-truth is considered right.
        n_classes: number of existent classes

    Returns:
        Average precision for the specified threshold.
    """
    # Initialize lists
    APs = []
    class_gt = []
    class_predictions = []

    # AP is computed for each class
    for c in range(n_classes):
        # Find gt and predictions of the class
        for gt in ground_truth:
            if gt[4] == c:
                class_gt.append(gt)
        for predict in predictions:
            if predict[4] == c:
                class_predictions.append(predict)

        # Create dict with array of zeros for bb in each image
        gt_amount_bb = Counter([gt[1] for gt in class_gt])
        for key, val in gt_amount_bb.items():
            gt_amount_bb[key] = np.zeros(val)

        # Sort class predictions by their score
        class_predictions = sorted(class_predictions, key=lambda x: x[5], reverse=True)

        # Create arrays for Positives (True and False)
        TP = np.zeros(len(class_predictions))
        FP = np.zeros(len(class_predictions))
        # Number of true boxes
        truth = len(class_gt)

        # Initializing aux variables
        epsilon = 1e-6

        # Iterate over predictions in each image and compare with ground truth
        for predict_idx, prediction in enumerate(class_predictions):
            # Filter prediction image ground truths
            image_gt = [obj for obj in class_gt if obj[1] == prediction[1]]

            # Initializing aux variables
            best_iou = -1
            best_gt_iou_idx = -1

            # Iterate through image ground truths and calculate IoUs
            for gt_idx, gt in enumerate(image_gt):
                iou = IOU(prediction[3], gt[3])
                if iou > best_iou:
                    best_iou = iou
                    best_gt_iou_idx = gt_idx

            # If the best IoU is greater that thresh than an TP prediction has been found
            if best_iou > iou_thresh and best_gt_iou_idx > -1:
                # Check if gt box was already covered
                if  gt_amount_bb[prediction[1]][best_gt_iou_idx] == 0:
                    gt_amount_bb[prediction[1]][best_gt_iou_idx] = 1  # set as covered
                    TP[predict_idx] = 1  # Count as true positive
                else:
                    FP[predict_idx] = 1
            else:
                FP[predict_idx] = 1

        # Calculate recall and precision
        TP_cumsum = np.cumsum(TP)
        FP_cumsum = np.cumsum(FP)
        recall = np.append([0], TP_cumsum / (truth + epsilon))
        precision = np.append([1], np.divide(TP_cumsum, (TP_cumsum + FP_cumsum + epsilon)))

        # Calculate the area precision/recall and add to list
        APs.append(np.trapz(precision, recall))

    return sum(APs)/len(APs)  # average of class precisions


def compute_mAP(ground_truth, predictions, n_classes):
    """
    Calls AP computation for different levels of IoUs, [0.5:.05:0.95].

    Args:
        ground_truth: list with ground-truth objects. Needs to have the following format: [sequence, frame, obj, [xmin, ymin, xmax, ymax], label, score]
        predictions: list with predictions objects. Needs to have the following format: [sequence, frame, obj, [xmin, ymin, xmax, ymax], label, score]
        n_classes: number of existent classes.

    Returns:
        mAp and list with APs for each IoU threshold.
    """
    # return mAP
    APs = [compute_AP(ground_truth, predictions, iou_thresh, n_classes) for iou_thresh in np.arange(0.5, 1.0, 0.05)]
    return np.mean(APs), APs

# %%
@torch.no_grad()
def evaluate(model, data_loader, device, sequences=1):
    """
    Evaluates model mAP for IoU range of [0.5:.05:0.95].

    Args:
        model: -
        data_loader: -
        device: -
        sequences: the number of sequences of images to pass, if any

    Returns:
        mAP and AP list for each IoU threshold in range [0.5:.05:0.95]
    """

    # Set evaluation mode flag
    model.eval()
    # Create list with all object detection -> [set, frame, obj, [xmin,ymin,xmax,ymax], label, score]
    ground_truth = []
    predictions = []

    # Gather all targets and outputs on test set
    for image, targets in data_loader:
        image = [img.to(device) for img in image]
        outputs = model(image)
        for idx in range(len(outputs)):
            outputs[idx] = apply_nms(outputs[idx], iou_thresh=0.5)

        # create list for targets and outputs to pass to compute_mAP()
        # lists have the following structure:  [sequence, frame, obj_idx, [xmin, ymin, xmax, ymax], label, score]
        for s in range(sequences):
            obj_gt = 0
            obj_target = 0
            for out, target in zip(outputs, targets):

                for i in range(len(target['boxes'])):
                    ground_truth.append([s, target['image_id'].detach().cpu().numpy()[0], obj_target,
                                         target['boxes'].detach().cpu().numpy()[i],
                                         target['labels'].detach().cpu().numpy()[i], 1])
                    obj_target += 1

                for j in range(len(out['boxes'])):
                    predictions.append([s, target['image_id'].detach().cpu().numpy()[0], obj_gt,
                                        out['boxes'].detach().cpu().numpy()[j],
                                        out['labels'].detach().cpu().numpy()[j],
                                        out['scores'].detach().cpu().numpy()[j]])
                    obj_gt += 1

    mAP, AP = compute_mAP(ground_truth, predictions, n_classes=4)
    print("mAP:{:.3f}".format(mAP))
    for ap_metric, iou in zip(AP, np.arange(0.5, 1, 0.05)):
        print("\tAP at IoU level [{:.2f}]: {:.3f}".format(iou, ap_metric))

    return mAP, AP

# %% [markdown]
# ### Create Dataset Class
#
# Dataset class to feed the dataloader.

# %%
# Create dataset object
class MyDataset(Dataset):

    # Constructor
    def __init__(self, ann_dir, img_dir, transform=None, mode='train'):

        # Image directories
        self.ann_dir = ann_dir
        self.img_dir = img_dir

        # The transform is goint to be used on image
        self.transform = transform

        # Create dataframe to hold info
        self.data = pd.DataFrame(columns=['Filename', 'BoundingBoxes', 'Labels', 'Area', 'N_Objects'])

        # Append rows with image filename and respective bounding boxes to the df
        for file in enumerate(os.listdir(img_dir)):

            # Find image annotation file
            ann_file_path = os.path.join(ann_dir, file[1][:-4]) + '.xml'

            # Read XML file and return bounding boxes and class attributes
            objects = self.read_XML_classf(ann_file_path)

            # Create list of labels in an image
            list_labels = encoded_labels(objects[0]['labels'])

            # Create list of bounding boxes in an image
            list_bb = []
            list_area = []
            n_obj = len(objects[0]['objects'])
            for i in objects[0]['objects']:
                list = [i['xmin'], i['ymin'], i['xmax'], i['ymax']]
                list_bb.append(list)
                list_area.append((i['xmax'] - i['xmin']) * (i['ymax'] - i['ymin']))

            # Create dataframe object with row containing [(Image file name),(Bounding Box List)]
            df = pd.DataFrame([[file[1], list_bb, list_labels, list_area, n_obj]],
                              columns=['Filename', 'BoundingBoxes', 'Labels', 'Area', 'N_Objects'])
            self.data = self.data.append(df)

        if mode == 'train':
            self.data = self.data[:680]
        elif mode == 'validation':
            self.data = self.data[680:700]
        elif mode == 'test':
            self.data = self.data[700:850]

        # Number of images in dataset
        self.len = self.data.shape[0]

        # Get the length

    def __len__(self):
        return self.len

    # Getter
    def __getitem__(self, idx):

        # Image file path
        img_name = os.path.join(self.img_dir, self.data.iloc[idx, 0])

        # Open image file and tranform to tensor
        img = Image.open(img_name).convert('RGB')

        # Get bounding box coordinates
        bbox = torch.tensor(self.data.iloc[idx, 1])

        # Get labels
        labels = torch.tensor(self.data.iloc[idx, 2])

        # Get bounding box areas
        area = torch.tensor(self.data.iloc[idx, 3])

        # If any, aplly tranformations to image and bounding box mask
        if self.transform:
            # Convert PIL image to numpy array
            img = np.array(img)
            # Apply transformations
            transformed = self.transform(image=img, bboxes=bbox)
            # Convert numpy array to PIL Image
            img = Image.fromarray(transformed['image'])
            # Get transformed bb
            bbox = torch.tensor(transformed['bboxes'])

        # suppose all instances are not crowd
        num_objs = self.data.iloc[idx, 4]
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        # Transform img to tensor
        img = torchvision.transforms.ToTensor()(img)

        # Build Targer dict
        target= {"boxes": bbox, "labels": labels, "image_id": torch.tensor([idx]), "area": area, "iscrowd": iscrowd}

        return img, target

    # XML reader -> returns dictionary with image bounding boxes sizes
    def read_XML_classf(self, ann_file_path):
        bboxes = [{
            'file': ann_file_path,
            'labels': [],
            'objects': []
        }]

        # Reading XML file objects and print Bounding Boxes
        tree = ET.parse(ann_file_path)
        root = tree.getroot()
        objects = root.findall('object')

        for obj in objects:
            # label
            label = obj.find('name').text
            bboxes[0]['labels'].append(label)

            # bbox dimensions
            bndbox = obj.find('bndbox')
            xmin = int(bndbox.find('xmin').text)
            ymin = int(bndbox.find('ymin').text)
            xmax = int(bndbox.find('xmax').text)
            ymax = int(bndbox.find('ymax').text)
            bboxes[0]['objects'].append({'xmin': xmin, 'ymin': ymin, 'xmax': xmax, 'ymax': ymax})

        return bboxes

# %% [markdown]
# ### Define Image Transformations

# %%
# Not in use
transform = A.Compose(
    [ A.HorizontalFlip(p=0.5), 
     A.RandomBrightnessContrast(p=0.4),
     A.Rotate(limit=40, p=0.8, border_mode = cv2.BORDER_CONSTANT)
    ],
    bbox_params= A.BboxParams(format='pascal_voc', min_visibility=0.2, label_fields=[])
)

# %% [markdown]
# ### Create Data Pipeline

# %%
# Create Data Pipeline

# Training Data
dataset_train = MyDataset(ann_directory,img_directory, mode = 'train')
loader_train = DataLoader(dataset_train, batch_size=4, shuffle=True, collate_fn=collate_fn)
# Validation Data
dataset_validation = MyDataset(ann_directory,img_directory, mode = 'validation')
loader_val = DataLoader(dataset_validation, batch_size=4, shuffle=True, collate_fn=collate_fn)
# Test Data
dataset_test = MyDataset(ann_directory,img_directory, mode = 'test')
loader_test = DataLoader(dataset_test, batch_size=4, shuffle=True, collate_fn=collate_fn)

# %% [markdown]
# Test if dataset is working correctly. Print out ground truth bounding box of first image.

# %%
# pick one image from the train set
img, target = dataset_train[0]
draw_bounding_boxes(img, target)
# Out:
# 301x400
# <PIL.Image.Image image mode=RGB size=301x400 at 0x7F29DEB8EC10>

# %% [markdown]
# ### Setting up the Faster R-CNN Model

# %%
# Setting up GPU device
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# Nº of classes: background, with_mask, mask_weared_incorrect, without_mask and build model (faster r-cnn)
num_classes = 4 
model = build_model(num_classes)

model = model.to(device)

# %%
# Set Hyper-parameters

# Network params
params = [p for p in model.parameters() if p.requires_grad]

# Optimizers
# optimizer = torch.optim.Adam(params, lr=0.01)
optimizer = torch.optim.SGD(params, lr=0.05)

# Learning Rate, lr decreases to half every 2 epochs 
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)

# Number of epochs to perform
epochs=50

# %% [markdown]
# ### Train the model

# %%
pip install git+https://github.com/gautamchitnis/cocoapi.git@cocodataset-master#subdirectory=PythonAPI
# Out:
# Collecting git+https://github.com/gautamchitnis/cocoapi.git@cocodataset-master#subdirectory=PythonAPI
#   Cloning https://github.com/gautamchitnis/cocoapi.git (to revision cocodataset-master) to /tmp/pip-req-build-r3hpl_95
#   Running command git clone -q https://github.com/gautamchitnis/cocoapi.git /tmp/pip-req-build-r3hpl_95
#   Running command git checkout -b cocodataset-master --track origin/cocodataset-master
#   Switched to a new branch 'cocodataset-master'
#   Branch 'cocodataset-master' set up to track remote branch 'cocodataset-master' from 'origin'.
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp37-cp37m-linux_x86_64.whl size=264247 sha256=d7148d2103ac6349ded6a3e1fbaf75be3d4c0e6b2d47ba96993621c3aafd177f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6aixf_2g/wheels/49/ca/2b/1b99c52bb9e7a9804cd60d66243ec70c9f15977795793d2646
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Found existing installation: pycocotools 2.0.2
#     Uninstalling pycocotools-2.0.2:
#       Successfully uninstalled pycocotools-2.0.2
# Successfully installed pycocotools-2.0

# %%
# !git clone https://github.com/pytorch/vision.git
# %cd vision
# !git checkout v0.3.0

# !cp references/detection/utils.py ../
# !cp references/detection/transforms.py ../
# !cp references/detection/coco_eval.py ../
# !cp references/detection/engine.py ../
# !cp references/detection/coco_utils.py ../
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 265, done.
# remote: Counting objects: 100% (265/265), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 18144 (delta 211), reused 183 (delta 141), pack-reused 17879
# Receiving objects: 100% (18144/18144), 16.98 MiB | 25.12 MiB/s, done.
# Resolving deltas: 100% (13173/13173), done.
# /content/vision
# Note: checking out 'v0.3.0'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at be376084 version check against PyTorch's CUDA version

# %%
from engine import train_one_epoch
# Training
for epoch in range(epochs):
    # train for one epoch, printing every 25 iterations
    train_one_epoch(model, optimizer, loader_train, device, epoch, print_freq=25)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, loader_val, device=device)
# Out:
# Epoch: [0]  [  0/170]  eta: 0:05:19  lr: 0.000346  loss: 2.2545 (2.2545)  loss_classifier: 1.4533 (1.4533)  loss_box_reg: 0.0478 (0.0478)  loss_objectness: 0.6986 (0.6986)  loss_rpn_box_reg: 0.0548 (0.0548)  time: 1.8807  data: 0.2892  max mem: 11685
# Epoch: [0]  [ 25/170]  eta: 0:04:14  lr: 0.007735  loss: 1.0697 (1.4088)  loss_classifier: 0.3317 (0.6995)  loss_box_reg: 0.0320 (0.0450)  loss_objectness: 0.6693 (0.6309)  loss_rpn_box_reg: 0.0219 (0.0333)  time: 1.7978  data: 0.3101  max mem: 11788
# Epoch: [0]  [ 50/170]  eta: 0:03:37  lr: 0.015124  loss: 0.5741 (1.0015)  loss_classifier: 0.2169 (0.4648)  loss_box_reg: 0.1770 (0.1036)  loss_objectness: 0.0926 (0.3955)  loss_rpn_box_reg: 0.0179 (0.0376)  time: 1.9221  data: 0.4132  max mem: 11859
# Epoch: [0]  [ 75/170]  eta: 0:02:51  lr: 0.022513  loss: 0.6769 (0.9011)  loss_classifier: 0.3232 (0.4164)  loss_box_reg: 0.2504 (0.1488)  loss_objectness: 0.1139 (0.3031)  loss_rpn_box_reg: 0.0189 (0.0329)  time: 1.7522  data: 0.3637  max mem: 11860
# Epoch: [0]  [100/170]  eta: 0:02:06  lr: 0.029902  loss: 0.5708 (0.8473)  loss_classifier: 0.2722 (0.3807)  loss_box_reg: 0.1855 (0.1692)  loss_objectness: 0.0963 (0.2640)  loss_rpn_box_reg: 0.0175 (0.0335)  time: 1.7310  data: 0.2452  max mem: 11860
# Epoch: [0]  [125/170]  eta: 0:01:21  lr: 0.037291  loss: 0.6767 (0.8240)  loss_classifier: 0.3143 (0.3685)  loss_box_reg: 0.3052 (0.1944)  loss_objectness: 0.0629 (0.2282)  loss_rpn_box_reg: 0.0242 (0.0328)  time: 1.8278  data: 0.3552  max mem: 12169
# Epoch: [0]  [150/170]  eta: 0:00:36  lr: 0.044680  loss: 0.6151 (0.8068)  loss_classifier: 0.2580 (0.3628)  loss_box_reg: 0.2956 (0.2057)  loss_objectness: 0.0680 (0.2064)  loss_rpn_box_reg: 0.0242 (0.0318)  time: 1.9070  data: 0.3740  max mem: 12169
# Epoch: [0]  [169/170]  eta: 0:00:01  lr: 0.050000  loss: 0.7148 (0.7949)  loss_classifier: 0.2338 (0.3496)  loss_box_reg: 0.3446 (0.2219)  loss_objectness: 0.0605 (0.1905)  loss_rpn_box_reg: 0.0407 (0.0330)  time: 1.7261  data: 0.3414  max mem: 12169
# Epoch: [0] Total time: 0:05:08 (1.8152 s / it)
# mAP:0.162
# 	AP at IoU level [0.50]: 0.463
# 	AP at IoU level [0.55]: 0.420
# 	AP at IoU level [0.60]: 0.363
# 	AP at IoU level [0.65]: 0.250
# 	AP at IoU level [0.70]: 0.108
# 	AP at IoU level [0.75]: 0.018
# 	AP at IoU level [0.80]: 0.002
# 	AP at IoU level [0.85]: 0.000
# 	AP at IoU level [0.90]: 0.000
# 	AP at IoU level [0.95]: 0.000
# Epoch: [1]  [  0/170]  eta: 0:05:33  lr: 0.050000  loss: 1.3111 (1.3111)  loss_classifier: 0.5164 (0.5164)  loss_box_reg: 0.6369 (0.6369)  loss_objectness: 0.1052 (0.1052)  loss_rpn_box_reg: 0.0526 (0.0526)  time: 1.9597  data: 0.0686  max mem: 12169
# Epoch: [1]  [ 25/170]  eta: 0:03:48  lr: 0.050000  loss: 0.5164 (0.5758)  loss_classifier: 0.1856 (0.2284)  loss_box_reg: 0.2761 (0.2863)  loss_objectness: 0.0287 (0.0391)  loss_rpn_box_reg: 0.0158 (0.0221)  time: 1.5527  data: 0.0605  max mem: 12169
# Epoch: [1]  [ 50/170]  eta: 0:03:07  lr: 0.050000  loss: 0.5728 (0.6036)  loss_classifier: 0.2037 (0.2250)  loss_box_reg: 0.3255 (0.3098)  loss_objectness: 0.0283 (0.0427)  loss_rpn_box_reg: 0.0186 (0.0260)  time: 1.5271  data: 0.0631  max mem: 12169
# Epoch: [1]  [ 75/170]  eta: 0:02:28  lr: 0.050000  loss: 0.5376 (0.6029)  loss_classifier: 0.2142 (0.2208)  loss_box_reg: 0.2783 (0.3120)  loss_objectness: 0.0192 (0.0437)  loss_rpn_box_reg: 0.0181 (0.0264)  time: 1.5686  data: 0.0605  max mem: 12169
# Epoch: [1]  [100/170]  eta: 0:01:49  lr: 0.050000  loss: 0.5588 (0.6030)  loss_classifier: 0.1944 (0.2170)  loss_box_reg: 0.2860 (0.3111)  loss_objectness: 0.0313 (0.0466)  loss_rpn_box_reg: 0.0249 (0.0285)  time: 1.5608  data: 0.0636  max mem: 12169
# Epoch: [1]  [125/170]  eta: 0:01:10  lr: 0.050000  loss: 0.4594 (0.5775)  loss_classifier: 0.1737 (0.2084)  loss_box_reg: 0.2521 (0.2992)  loss_objectness: 0.0237 (0.0435)  loss_rpn_box_reg: 0.0142 (0.0264)  time: 1.5841  data: 0.0616  max mem: 12169
# Epoch: [1]  [150/170]  eta: 0:00:31  lr: 0.050000  loss: 0.4221 (0.5538)  loss_classifier: 0.1178 (0.1953)  loss_box_reg: 0.1751 (0.2880)  loss_objectness: 0.0156 (0.0445)  loss_rpn_box_reg: 0.0144 (0.0260)  time: 1.5342  data: 0.0571  max mem: 12169
# Epoch: [1]  [169/170]  eta: 0:00:01  lr: 0.050000  loss: 0.4415 (0.5551)  loss_classifier: 0.1476 (0.1944)  loss_box_reg: 0.2646 (0.2910)  loss_objectness: 0.0192 (0.0433)  loss_rpn_box_reg: 0.0188 (0.0264)  time: 1.4742  data: 0.0622  max mem: 12169
# Epoch: [1] Total time: 0:04:22 (1.5462 s / it)
# mAP:0.370
# 	AP at IoU level [0.50]: 0.725
# 	AP at IoU level [0.55]: 0.722
# 	AP at IoU level [0.60]: 0.719
# 	AP at IoU level [0.65]: 0.680
# 	AP at IoU level [0.70]: 0.479
# 	AP at IoU level [0.75]: 0.262
# 	AP at IoU level [0.80]: 0.086
# 	AP at IoU level [0.85]: 0.025
# 	AP at IoU level [0.90]: 0.001
# 	AP at IoU level [0.95]: 0.000
# Epoch: [2]  [  0/170]  eta: 0:03:40  lr: 0.050000  loss: 0.8104 (0.8104)  loss_classifier: 0.2135 (0.2135)  loss_box_reg: 0.4237 (0.4237)  loss_objectness: 0.0947 (0.0947)  loss_rpn_box_reg: 0.0784 (0.0784)  time: 1.2944  data: 0.0727  max mem: 12169
# Epoch: [2]  [ 25/170]  eta: 0:03:41  lr: 0.050000  loss: 0.4408 (0.4660)  loss_classifier: 0.1344 (0.1515)  loss_box_reg: 0.2710 (0.2692)  loss_objectness: 0.0188 (0.0239)  loss_rpn_box_reg: 0.0150 (0.0215)  time: 1.5155  data: 0.0599  max mem: 12169
# Epoch: [2]  [ 50/170]  eta: 0:03:02  lr: 0.050000  loss: 0.3212 (0.4544)  loss_classifier: 0.0961 (0.1533)  loss_box_reg: 0.1879 (0.2606)  loss_objectness: 0.0110 (0.0211)  loss_rpn_box_reg: 0.0101 (0.0194)  time: 1.4988  data: 0.0597  max mem: 12169
# Epoch: [2]  [ 75/170]  eta: 0:02:27  lr: 0.050000  loss: 0.3386 (0.4354)  loss_classifier: 0.1170 (0.1460)  loss_box_reg: 0.2099 (0.2527)  loss_objectness: 0.0091 (0.0190)  loss_rpn_box_reg: 0.0096 (0.0178)  time: 1.6239  data: 0.0595  max mem: 12169
# Epoch: [2]  [100/170]  eta: 0:01:48  lr: 0.050000  loss: 0.3631 (0.4307)  loss_classifier: 0.1122 (0.1429)  loss_box_reg: 0.2096 (0.2513)  loss_objectness: 0.0112 (0.0186)  loss_rpn_box_reg: 0.0119 (0.0179)  time: 1.5248  data: 0.0626  max mem: 12169
# Epoch: [2]  [125/170]  eta: 0:01:09  lr: 0.050000  loss: 0.4273 (0.4354)  loss_classifier: 0.1260 (0.1431)  loss_box_reg: 0.2452 (0.2540)  loss_objectness: 0.0113 (0.0200)  loss_rpn_box_reg: 0.0130 (0.0183)  time: 1.5057  data: 0.0605  max mem: 12169
# Epoch: [2]  [150/170]  eta: 0:00:30  lr: 0.050000  loss: 0.3372 (0.4309)  loss_classifier: 0.1091 (0.1421)  loss_box_reg: 0.1754 (0.2495)  loss_objectness: 0.0104 (0.0199)  loss_rpn_box_reg: 0.0098 (0.0194)  time: 1.5859  data: 0.0579  max mem: 12169
# Epoch: [2]  [169/170]  eta: 0:00:01  lr: 0.050000  loss: 0.4234 (0.4398)  loss_classifier: 0.1404 (0.1467)  loss_box_reg: 0.2527 (0.2529)  loss_objectness: 0.0149 (0.0206)  loss_rpn_box_reg: 0.0144 (0.0195)  time: 1.5286  data: 0.0639  max mem: 12169
# Epoch: [2] Total time: 0:04:21 (1.5403 s / it)
# mAP:0.449
# 	AP at IoU level [0.50]: 0.735
# 	AP at IoU level [0.55]: 0.722
# 	AP at IoU level [0.60]: 0.711
# 	AP at IoU level [0.65]: 0.685
# 	AP at IoU level [0.70]: 0.594
# 	AP at IoU level [0.75]: 0.514
# 	AP at IoU level [0.80]: 0.364
# 	AP at IoU level [0.85]: 0.137
# 	AP at IoU level [0.90]: 0.029
# 	AP at IoU level [0.95]: 0.000
# Epoch: [3]  [  0/170]  eta: 0:04:14  lr: 0.050000  loss: 0.3522 (0.3522)  loss_classifier: 0.0957 (0.0957)  loss_box_reg: 0.2290 (0.2290)  loss_objectness: 0.0061 (0.0061)  loss_rpn_box_reg: 0.0213 (0.0213)  time: 1.4943  data: 0.0787  max mem: 12169
# Epoch: [3]  [ 25/170]  eta: 0:03:35  lr: 0.050000  loss: 0.3789 (0.4227)  loss_classifier: 0.1300 (0.1507)  loss_box_reg: 0.2099 (0.2416)  loss_objectness: 0.0118 (0.0142)  loss_rpn_box_reg: 0.0138 (0.0162)  time: 1.4758  data: 0.0587  max mem: 12169
# Epoch: [3]  [ 50/170]  eta: 0:03:02  lr: 0.050000  loss: 0.4077 (0.4197)  loss_classifier: 0.1408 (0.1428)  loss_box_reg: 0.2283 (0.2372)  loss_objectness: 0.0116 (0.0179)  loss_rpn_box_reg: 0.0123 (0.0218)  time: 1.5647  data: 0.0614  max mem: 12169
# Epoch: [3]  [ 75/170]  eta: 0:02:23  lr: 0.050000  loss: 0.4901 (0.4365)  loss_classifier: 0.1470 (0.1457)  loss_box_reg: 0.2968 (0.2520)  loss_objectness: 0.0105 (0.0175)  loss_rpn_box_reg: 0.0161 (0.0213)  time: 1.4364  data: 0.0626  max mem: 12169
# Epoch: [3]  [100/170]  eta: 0:01:45  lr: 0.050000  loss: 0.3670 (0.4345)  loss_classifier: 0.1264 (0.1437)  loss_box_reg: 0.2245 (0.2534)  loss_objectness: 0.0089 (0.0167)  loss_rpn_box_reg: 0.0117 (0.0207)  time: 1.5308  data: 0.0581  max mem: 12169
# Epoch: [3]  [125/170]  eta: 0:01:07  lr: 0.050000  loss: 0.3140 (0.4112)  loss_classifier: 0.0994 (0.1352)  loss_box_reg: 0.2132 (0.2425)  loss_objectness: 0.0079 (0.0152)  loss_rpn_box_reg: 0.0069 (0.0183)  time: 1.4931  data: 0.0592  max mem: 12169
# Epoch: [3]  [150/170]  eta: 0:00:30  lr: 0.050000  loss: 0.3213 (0.3986)  loss_classifier: 0.0959 (0.1313)  loss_box_reg: 0.1807 (0.2360)  loss_objectness: 0.0073 (0.0142)  loss_rpn_box_reg: 0.0083 (0.0171)  time: 1.5386  data: 0.0601  max mem: 12169
# Epoch: [3]  [169/170]  eta: 0:00:01  lr: 0.050000  loss: 0.3210 (0.3914)  loss_classifier: 0.0999 (0.1289)  loss_box_reg: 0.2040 (0.2325)  loss_objectness: 0.0066 (0.0136)  loss_rpn_box_reg: 0.0091 (0.0164)  time: 1.6411  data: 0.0647  max mem: 12169
# Epoch: [3] Total time: 0:04:20 (1.5312 s / it)
# mAP:0.260
# 	AP at IoU level [0.50]: 0.726
# 	AP at IoU level [0.55]: 0.714
# 	AP at IoU level [0.60]: 0.624
# 	AP at IoU level [0.65]: 0.391
# 	AP at IoU level [0.70]: 0.102
# 	AP at IoU level [0.75]: 0.033
# 	AP at IoU level [0.80]: 0.005
# 	AP at IoU level [0.85]: 0.000
# 	AP at IoU level [0.90]: 0.000
# 	AP at IoU level [0.95]: 0.000
# Epoch: [4]  [  0/170]  eta: 0:04:31  lr: 0.050000  loss: 0.1430 (0.1430)  loss_classifier: 0.0243 (0.0243)  loss_box_reg: 0.1102 (0.1102)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0078 (0.0078)  time: 1.5942  data: 0.0590  max mem: 12169
# Epoch: [4]  [ 25/170]  eta: 0:03:54  lr: 0.050000  loss: 0.2715 (0.3453)  loss_classifier: 0.0822 (0.1062)  loss_box_reg: 0.1984 (0.2141)  loss_objectness: 0.0049 (0.0098)  loss_rpn_box_reg: 0.0079 (0.0153)  time: 1.6071  data: 0.0620  max mem: 12169
# Epoch: [4]  [ 50/170]  eta: 0:03:07  lr: 0.050000  loss: 0.3709 (0.3787)  loss_classifier: 0.1138 (0.1241)  loss_box_reg: 0.2436 (0.2264)  loss_objectness: 0.0092 (0.0116)  loss_rpn_box_reg: 0.0126 (0.0165)  time: 1.4810  data: 0.0600  max mem: 12169
# Epoch: [4]  [ 75/170]  eta: 0:02:26  lr: 0.050000  loss: 0.5445 (0.5418)  loss_classifier: 0.2246 (0.2019)  loss_box_reg: 0.2216 (0.2191)  loss_objectness: 0.0712 (0.0922)  loss_rpn_box_reg: 0.0227 (0.0286)  time: 1.4662  data: 0.0657  max mem: 12169
# Epoch: [4]  [100/170]  eta: 0:01:46  lr: 0.050000  loss: 0.3282 (0.5065)  loss_classifier: 0.1247 (0.1878)  loss_box_reg: 0.1551 (0.2114)  loss_objectness: 0.0159 (0.0814)  loss_rpn_box_reg: 0.0089 (0.0258)  time: 1.4705  data: 0.0591  max mem: 12169
# Epoch: [4]  [125/170]  eta: 0:01:08  lr: 0.050000  loss: 0.3131 (0.4808)  loss_classifier: 0.0947 (0.1751)  loss_box_reg: 0.1641 (0.2134)  loss_objectness: 0.0112 (0.0684)  loss_rpn_box_reg: 0.0114 (0.0240)  time: 1.5082  data: 0.0602  max mem: 12169
# Epoch: [4]  [150/170]  eta: 0:00:30  lr: 0.050000  loss: 0.3128 (0.4640)  loss_classifier: 0.1110 (0.1662)  loss_box_reg: 0.1840 (0.2118)  loss_objectness: 0.0122 (0.0621)  loss_rpn_box_reg: 0.0088 (0.0239)  time: 1.5058  data: 0.0606  max mem: 12169
# Epoch: [4]  [169/170]  eta: 0:00:01  lr: 0.050000  loss: 0.4356 (0.4566)  loss_classifier: 0.1415 (0.1622)  loss_box_reg: 0.2632 (0.2147)  loss_objectness: 0.0105 (0.0569)  loss_rpn_box_reg: 0.0084 (0.0229)  time: 1.5177  data: 0.0627  max mem: 12169
# Epoch: [4] Total time: 0:04:19 (1.5293 s / it)
# mAP:0.431
# 	AP at IoU level [0.50]: 0.731
# 	AP at IoU level [0.55]: 0.716
# 	AP at IoU level [0.60]: 0.713
# 	AP at IoU level [0.65]: 0.669
# 	AP at IoU level [0.70]: 0.587
# 	AP at IoU level [0.75]: 0.498
# 	AP at IoU level [0.80]: 0.268
# 	AP at IoU level [0.85]: 0.098
# 	AP at IoU level [0.90]: 0.031
# 	AP at IoU level [0.95]: 0.000
# Epoch: [5]  [  0/170]  eta: 0:03:35  lr: 0.025000  loss: 0.5746 (0.5746)  loss_classifier: 0.1906 (0.1906)  loss_box_reg: 0.3287 (0.3287)  loss_objectness: 0.0364 (0.0364)  loss_rpn_box_reg: 0.0189 (0.0189)  time: 1.2658  data: 0.0607  max mem: 12169
# Epoch: [5]  [ 25/170]  eta: 0:03:35  lr: 0.025000  loss: 0.2823 (0.3345)  loss_classifier: 0.0868 (0.1128)  loss_box_reg: 0.1844 (0.1986)  loss_objectness: 0.0088 (0.0122)  loss_rpn_box_reg: 0.0074 (0.0109)  time: 1.5087  data: 0.0636  max mem: 12169
# Epoch: [5]  [ 50/170]  eta: 0:03:00  lr: 0.025000  loss: 0.2531 (0.3071)  loss_classifier: 0.0830 (0.1049)  loss_box_reg: 0.1485 (0.1802)  loss_objectness: 0.0055 (0.0112)  loss_rpn_box_reg: 0.0054 (0.0107)  time: 1.5838  data: 0.0601  max mem: 12169
# Epoch: [5]  [ 75/170]  eta: 0:02:24  lr: 0.025000  loss: 0.2491 (0.2937)  loss_classifier: 0.0862 (0.0991)  loss_box_reg: 0.1410 (0.1749)  loss_objectness: 0.0061 (0.0100)  loss_rpn_box_reg: 0.0054 (0.0098)  time: 1.5444  data: 0.0611  max mem: 12169
# Epoch: [5]  [100/170]  eta: 0:01:46  lr: 0.025000  loss: 0.2902 (0.2940)  loss_classifier: 0.0936 (0.0992)  loss_box_reg: 0.1712 (0.1736)  loss_objectness: 0.0041 (0.0102)  loss_rpn_box_reg: 0.0071 (0.0110)  time: 1.5485  data: 0.0610  max mem: 12169
# Epoch: [5]  [125/170]  eta: 0:01:08  lr: 0.025000  loss: 0.3005 (0.3005)  loss_classifier: 0.0925 (0.1007)  loss_box_reg: 0.1853 (0.1773)  loss_objectness: 0.0068 (0.0106)  loss_rpn_box_reg: 0.0107 (0.0118)  time: 1.5809  data: 0.0599  max mem: 12169
# Epoch: [5]  [150/170]  eta: 0:00:30  lr: 0.025000  loss: 0.2799 (0.3017)  loss_classifier: 0.0881 (0.1005)  loss_box_reg: 0.1816 (0.1790)  loss_objectness: 0.0054 (0.0104)  loss_rpn_box_reg: 0.0083 (0.0118)  time: 1.6009  data: 0.0621  max mem: 12169
# Epoch: [5]  [169/170]  eta: 0:00:01  lr: 0.025000  loss: 0.2357 (0.2955)  loss_classifier: 0.0770 (0.0983)  loss_box_reg: 0.1435 (0.1756)  loss_objectness: 0.0033 (0.0101)  loss_rpn_box_reg: 0.0060 (0.0115)  time: 1.5327  data: 0.0590  max mem: 12169
# Epoch: [5] Total time: 0:04:22 (1.5462 s / it)
# mAP:0.504
# 	AP at IoU level [0.50]: 0.737
# 	AP at IoU level [0.55]: 0.737
# 	AP at IoU level [0.60]: 0.724
# 	AP at IoU level [0.65]: 0.700
# 	AP at IoU level [0.70]: 0.681
# 	AP at IoU level [0.75]: 0.633
# 	AP at IoU level [0.80]: 0.502
# 	AP at IoU level [0.85]: 0.243
# 	AP at IoU level [0.90]: 0.079
# 	AP at IoU level [0.95]: 0.000
# Epoch: [6]  [  0/170]  eta: 0:03:57  lr: 0.025000  loss: 0.1561 (0.1561)  loss_classifier: 0.0490 (0.0490)  loss_box_reg: 0.0954 (0.0954)  loss_objectness: 0.0068 (0.0068)  loss_rpn_box_reg: 0.0048 (0.0048)  time: 1.3960  data: 0.0612  max mem: 12169
# Epoch: [6]  [ 25/170]  eta: 0:03:40  lr: 0.025000  loss: 0.2729 (0.2660)  loss_classifier: 0.0891 (0.0895)  loss_box_reg: 0.1565 (0.1562)  loss_objectness: 0.0089 (0.0087)  loss_rpn_box_reg: 0.0092 (0.0115)  time: 1.5207  data: 0.0598  max mem: 12255
# Epoch: [6]  [ 50/170]  eta: 0:03:06  lr: 0.025000  loss: 0.2804 (0.2865)  loss_classifier: 0.0876 (0.0942)  loss_box_reg: 0.1691 (0.1706)  loss_objectness: 0.0062 (0.0090)  loss_rpn_box_reg: 0.0092 (0.0128)  time: 1.6164  data: 0.0635  max mem: 12255
# Epoch: [6]  [ 75/170]  eta: 0:02:26  lr: 0.025000  loss: 0.2749 (0.2901)  loss_classifier: 0.0885 (0.0945)  loss_box_reg: 0.1478 (0.1731)  loss_objectness: 0.0074 (0.0096)  loss_rpn_box_reg: 0.0111 (0.0129)  time: 1.5232  data: 0.0630  max mem: 12255
# Epoch: [6]  [100/170]  eta: 0:01:47  lr: 0.025000  loss: 0.2378 (0.2849)  loss_classifier: 0.0792 (0.0923)  loss_box_reg: 0.1514 (0.1717)  loss_objectness: 0.0048 (0.0087)  loss_rpn_box_reg: 0.0056 (0.0122)  time: 1.5301  data: 0.0606  max mem: 12255
# Epoch: [7]  [125/170]  eta: 0:01:10  lr: 0.025000  loss: 0.2239 (0.2591)  loss_classifier: 0.0785 (0.0844)  loss_box_reg: 0.1414 (0.1581)  loss_objectness: 0.0030 (0.0064)  loss_rpn_box_reg: 0.0064 (0.0101)  time: 1.5423  data: 0.0601  max mem: 12255
# Epoch: [7]  [150/170]  eta: 0:00:31  lr: 0.025000  loss: 0.2620 (0.2588)  loss_classifier: 0.0745 (0.0832)  loss_box_reg: 0.1721 (0.1596)  loss_objectness: 0.0046 (0.0062)  loss_rpn_box_reg: 0.0058 (0.0098)  time: 1.4917  data: 0.0626  max mem: 12255
# Epoch: [7]  [169/170]  eta: 0:00:01  lr: 0.025000  loss: 0.2564 (0.2591)  loss_classifier: 0.0760 (0.0828)  loss_box_reg: 0.1631 (0.1600)  loss_objectness: 0.0034 (0.0064)  loss_rpn_box_reg: 0.0083 (0.0099)  time: 1.5444  data: 0.0632  max mem: 12255
# Epoch: [7] Total time: 0:04:23 (1.5510 s / it)
# mAP:0.485
# 	AP at IoU level [0.50]: 0.739
# 	AP at IoU level [0.55]: 0.739
# 	AP at IoU level [0.60]: 0.739
# 	AP at IoU level [0.65]: 0.706
# 	AP at IoU level [0.70]: 0.654
# 	AP at IoU level [0.75]: 0.541
# 	AP at IoU level [0.80]: 0.437
# 	AP at IoU level [0.85]: 0.269
# 	AP at IoU level [0.90]: 0.027
# 	AP at IoU level [0.95]: 0.003
# Epoch: [8]  [  0/170]  eta: 0:04:30  lr: 0.025000  loss: 0.2298 (0.2298)  loss_classifier: 0.0698 (0.0698)  loss_box_reg: 0.1482 (0.1482)  loss_objectness: 0.0072 (0.0072)  loss_rpn_box_reg: 0.0045 (0.0045)  time: 1.5941  data: 0.0553  max mem: 12255
# Epoch: [8]  [ 25/170]  eta: 0:03:43  lr: 0.025000  loss: 0.1860 (0.2141)  loss_classifier: 0.0498 (0.0678)  loss_box_reg: 0.1271 (0.1349)  loss_objectness: 0.0027 (0.0044)  loss_rpn_box_reg: 0.0060 (0.0069)  time: 1.5029  data: 0.0588  max mem: 12255
# Epoch: [8]  [ 50/170]  eta: 0:03:03  lr: 0.025000  loss: 0.2693 (0.2523)  loss_classifier: 0.0818 (0.0793)  loss_box_reg: 0.1522 (0.1553)  loss_objectness: 0.0048 (0.0060)  loss_rpn_box_reg: 0.0114 (0.0117)  time: 1.5426  data: 0.0605  max mem: 12255
# Epoch: [8]  [ 75/170]  eta: 0:02:26  lr: 0.025000  loss: 0.2104 (0.2410)  loss_classifier: 0.0551 (0.0764)  loss_box_reg: 0.1423 (0.1496)  loss_objectness: 0.0031 (0.0052)  loss_rpn_box_reg: 0.0045 (0.0098)  time: 1.5749  data: 0.0598  max mem: 12255
# Epoch: [8]  [100/170]  eta: 0:01:46  lr: 0.025000  loss: 0.2591 (0.2399)  loss_classifier: 0.0750 (0.0762)  loss_box_reg: 0.1718 (0.1494)  loss_objectness: 0.0033 (0.0051)  loss_rpn_box_reg: 0.0047 (0.0093)  time: 1.4732  data: 0.0633  max mem: 12255
# Epoch: [9]  [125/170]  eta: 0:01:08  lr: 0.025000  loss: 0.1943 (0.2417)  loss_classifier: 0.0590 (0.0769)  loss_box_reg: 0.1193 (0.1506)  loss_objectness: 0.0026 (0.0050)  loss_rpn_box_reg: 0.0052 (0.0092)  time: 1.5001  data: 0.0637  max mem: 12255
# Epoch: [9]  [150/170]  eta: 0:00:30  lr: 0.025000  loss: 0.1725 (0.2349)  loss_classifier: 0.0557 (0.0743)  loss_box_reg: 0.1087 (0.1472)  loss_objectness: 0.0019 (0.0045)  loss_rpn_box_reg: 0.0038 (0.0088)  time: 1.5908  data: 0.0561  max mem: 12255
# Epoch: [9]  [169/170]  eta: 0:00:01  lr: 0.025000  loss: 0.1997 (0.2344)  loss_classifier: 0.0630 (0.0738)  loss_box_reg: 0.1303 (0.1467)  loss_objectness: 0.0030 (0.0046)  loss_rpn_box_reg: 0.0044 (0.0092)  time: 1.5960  data: 0.0632  max mem: 12255
# Epoch: [9] Total time: 0:04:22 (1.5469 s / it)
# mAP:0.492
# 	AP at IoU level [0.50]: 0.730
# 	AP at IoU level [0.55]: 0.724
# 	AP at IoU level [0.60]: 0.724
# 	AP at IoU level [0.65]: 0.690
# 	AP at IoU level [0.70]: 0.649
# 	AP at IoU level [0.75]: 0.576
# 	AP at IoU level [0.80]: 0.494
# 	AP at IoU level [0.85]: 0.254
# 	AP at IoU level [0.90]: 0.082
# 	AP at IoU level [0.95]: 0.001
# Epoch: [10]  [  0/170]  eta: 0:03:34  lr: 0.012500  loss: 0.1642 (0.1642)  loss_classifier: 0.0567 (0.0567)  loss_box_reg: 0.1042 (0.1042)  loss_objectness: 0.0011 (0.0011)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 1.2625  data: 0.0617  max mem: 12255
# Epoch: [10]  [ 25/170]  eta: 0:03:38  lr: 0.012500  loss: 0.1656 (0.1925)  loss_classifier: 0.0521 (0.0644)  loss_box_reg: 0.1049 (0.1166)  loss_objectness: 0.0022 (0.0028)  loss_rpn_box_reg: 0.0038 (0.0085)  time: 1.5136  data: 0.0625  max mem: 12255
# Epoch: [10]  [ 50/170]  eta: 0:03:06  lr: 0.012500  loss: 0.2119 (0.2045)  loss_classifier: 0.0710 (0.0685)  loss_box_reg: 0.1268 (0.1237)  loss_objectness: 0.0020 (0.0036)  loss_rpn_box_reg: 0.0076 (0.0087)  time: 1.5908  data: 0.0614  max mem: 12255
# Epoch: [10]  [ 75/170]  eta: 0:02:26  lr: 0.012500  loss: 0.1887 (0.1986)  loss_classifier: 0.0591 (0.0669)  loss_box_reg: 0.1047 (0.1204)  loss_objectness: 0.0016 (0.0033)  loss_rpn_box_reg: 0.0043 (0.0079)  time: 1.4982  data: 0.0615  max mem: 12255
# Epoch: [10]  [100/170]  eta: 0:01:47  lr: 0.012500  loss: 0.1616 (0.1937)  loss_classifier: 0.0568 (0.0650)  loss_box_reg: 0.1022 (0.1174)  loss_objectness: 0.0024 (0.0035)  loss_rpn_box_reg: 0.0041 (0.0077)  time: 1.5245  data: 0.0586  max mem: 12255
# Epoch: [10]  [125/170]  eta: 0:01:09  lr: 0.012500  loss: 0.2078 (0.2006)  loss_classifier: 0.0726 (0.0667)  loss_box_reg: 0.1354 (0.1218)  loss_objectness: 0.0017 (0.0041)  loss_rpn_box_reg: 0.0052 (0.0080)  time: 1.5966  data: 0.0605  max mem: 12255
# Epoch: [10]  [150/170]  eta: 0:00:30  lr: 0.012500  loss: 0.2075 (0.2007)  loss_classifier: 0.0700 (0.0665)  loss_box_reg: 0.1208 (0.1226)  loss_objectness: 0.0023 (0.0040)  loss_rpn_box_reg: 0.0041 (0.0075)  time: 1.5721  data: 0.0611  max mem: 12255
# Epoch: [10]  [169/170]  eta: 0:00:01  lr: 0.012500  loss: 0.1414 (0.1955)  loss_classifier: 0.0420 (0.0649)  loss_box_reg: 0.0961 (0.1194)  loss_objectness: 0.0019 (0.0039)  loss_rpn_box_reg: 0.0031 (0.0073)  time: 1.5965  data: 0.0597  max mem: 12255
# Epoch: [10] Total time: 0:04:22 (1.5454 s / it)
# mAP:0.504
# 	AP at IoU level [0.50]: 0.740
# 	AP at IoU level [0.55]: 0.740
# 	AP at IoU level [0.60]: 0.733
# 	AP at IoU level [0.65]: 0.711
# 	AP at IoU level [0.70]: 0.653
# 	AP at IoU level [0.75]: 0.556
# 	AP at IoU level [0.80]: 0.517
# 	AP at IoU level [0.85]: 0.300
# 	AP at IoU level [0.90]: 0.089
# 	AP at IoU level [0.95]: 0.003
# Epoch: [11]  [  0/170]  eta: 0:03:14  lr: 0.012500  loss: 0.0869 (0.0869)  loss_classifier: 0.0322 (0.0322)  loss_box_reg: 0.0526 (0.0526)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 1.1446  data: 0.0429  max mem: 12255
# Epoch: [11]  [ 25/170]  eta: 0:03:27  lr: 0.012500  loss: 0.1402 (0.1704)  loss_classifier: 0.0456 (0.0571)  loss_box_reg: 0.0881 (0.1030)  loss_objectness: 0.0016 (0.0041)  loss_rpn_box_reg: 0.0031 (0.0063)  time: 1.3765  data: 0.0655  max mem: 12255
# Epoch: [11]  [ 50/170]  eta: 0:02:58  lr: 0.012500  loss: 0.1999 (0.1919)  loss_classifier: 0.0658 (0.0643)  loss_box_reg: 0.1298 (0.1157)  loss_objectness: 0.0018 (0.0038)  loss_rpn_box_reg: 0.0057 (0.0080)  time: 1.5775  data: 0.0622  max mem: 12255
# Epoch: [11]  [ 75/170]  eta: 0:02:21  lr: 0.012500  loss: 0.2102 (0.1929)  loss_classifier: 0.0646 (0.0639)  loss_box_reg: 0.1268 (0.1175)  loss_objectness: 0.0034 (0.0040)  loss_rpn_box_reg: 0.0044 (0.0075)  time: 1.5149  data: 0.0617  max mem: 13074
# Epoch: [11]  [100/170]  eta: 0:01:44  lr: 0.012500  loss: 0.1293 (0.1866)  loss_classifier: 0.0458 (0.0617)  loss_box_reg: 0.0769 (0.1138)  loss_objectness: 0.0013 (0.0038)  loss_rpn_box_reg: 0.0035 (0.0073)  time: 1.5018  data: 0.0604  max mem: 13074
# Epoch: [15]  [125/170]  eta: 0:01:09  lr: 0.006250  loss: 0.1547 (0.1473)  loss_classifier: 0.0539 (0.0511)  loss_box_reg: 0.0918 (0.0880)  loss_objectness: 0.0014 (0.0028)  loss_rpn_box_reg: 0.0035 (0.0053)  time: 1.4876  data: 0.0617  max mem: 13074
# Epoch: [15]  [150/170]  eta: 0:00:30  lr: 0.006250  loss: 0.1392 (0.1487)  loss_classifier: 0.0459 (0.0517)  loss_box_reg: 0.0808 (0.0884)  loss_objectness: 0.0015 (0.0028)  loss_rpn_box_reg: 0.0041 (0.0058)  time: 1.5462  data: 0.0625  max mem: 13074
# Epoch: [15]  [169/170]  eta: 0:00:01  lr: 0.006250  loss: 0.1090 (0.1452)  loss_classifier: 0.0361 (0.0505)  loss_box_reg: 0.0645 (0.0864)  loss_objectness: 0.0008 (0.0027)  loss_rpn_box_reg: 0.0025 (0.0056)  time: 1.5310  data: 0.0580  max mem: 13074
# Epoch: [15] Total time: 0:04:21 (1.5378 s / it)
# mAP:0.511
# 	AP at IoU level [0.50]: 0.739
# 	AP at IoU level [0.55]: 0.739
# 	AP at IoU level [0.60]: 0.722
# 	AP at IoU level [0.65]: 0.696
# 	AP at IoU level [0.70]: 0.652
# 	AP at IoU level [0.75]: 0.614
# 	AP at IoU level [0.80]: 0.516
# 	AP at IoU level [0.85]: 0.339
# 	AP at IoU level [0.90]: 0.093
# 	AP at IoU level [0.95]: 0.002
# Epoch: [16]  [  0/170]  eta: 0:03:34  lr: 0.006250  loss: 0.1074 (0.1074)  loss_classifier: 0.0383 (0.0383)  loss_box_reg: 0.0646 (0.0646)  loss_objectness: 0.0016 (0.0016)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 1.2601  data: 0.0680  max mem: 13074
# Epoch: [16]  [ 25/170]  eta: 0:03:42  lr: 0.006250  loss: 0.1064 (0.1192)  loss_classifier: 0.0400 (0.0435)  loss_box_reg: 0.0610 (0.0706)  loss_objectness: 0.0017 (0.0019)  loss_rpn_box_reg: 0.0024 (0.0032)  time: 1.5376  data: 0.0606  max mem: 13074
# Epoch: [16]  [ 50/170]  eta: 0:03:03  lr: 0.006250  loss: 0.1345 (0.1309)  loss_classifier: 0.0465 (0.0469)  loss_box_reg: 0.0763 (0.0779)  loss_objectness: 0.0009 (0.0021)  loss_rpn_box_reg: 0.0030 (0.0039)  time: 1.5230  data: 0.0599  max mem: 13074
# Epoch: [16]  [ 75/170]  eta: 0:02:26  lr: 0.006250  loss: 0.1365 (0.1341)  loss_classifier: 0.0449 (0.0477)  loss_box_reg: 0.0826 (0.0793)  loss_objectness: 0.0009 (0.0020)  loss_rpn_box_reg: 0.0035 (0.0051)  time: 1.5702  data: 0.0606  max mem: 13074
# Epoch: [16]  [100/170]  eta: 0:01:48  lr: 0.006250  loss: 0.1399 (0.1357)  loss_classifier: 0.0438 (0.0476)  loss_box_reg: 0.0921 (0.0806)  loss_objectness: 0.0012 (0.0021)  loss_rpn_box_reg: 0.0029 (0.0054)  time: 1.5633  data: 0.0612  max mem: 13074
# Epoch: [44] Total time: 0:04:21 (1.5375 s / it)
# mAP:0.508
# 	AP at IoU level [0.50]: 0.739
# 	AP at IoU level [0.55]: 0.739
# 	AP at IoU level [0.60]: 0.723
# 	AP at IoU level [0.65]: 0.704
# 	AP at IoU level [0.70]: 0.681
# 	AP at IoU level [0.75]: 0.566
# 	AP at IoU level [0.80]: 0.529
# 	AP at IoU level [0.85]: 0.333
# 	AP at IoU level [0.90]: 0.070
# 	AP at IoU level [0.95]: 0.000
# Epoch: [45]  [  0/170]  eta: 0:04:31  lr: 0.000098  loss: 0.0523 (0.0523)  loss_classifier: 0.0239 (0.0239)  loss_box_reg: 0.0276 (0.0276)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.5984  data: 0.0553  max mem: 13074
# Epoch: [45]  [ 25/170]  eta: 0:03:33  lr: 0.000098  loss: 0.0739 (0.1006)  loss_classifier: 0.0314 (0.0368)  loss_box_reg: 0.0396 (0.0576)  loss_objectness: 0.0003 (0.0017)  loss_rpn_box_reg: 0.0017 (0.0046)  time: 1.4756  data: 0.0598  max mem: 13074
# Epoch: [45]  [ 50/170]  eta: 0:02:58  lr: 0.000098  loss: 0.1060 (0.1038)  loss_classifier: 0.0356 (0.0394)  loss_box_reg: 0.0619 (0.0583)  loss_objectness: 0.0006 (0.0020)  loss_rpn_box_reg: 0.0031 (0.0041)  time: 1.4661  data: 0.0627  max mem: 13074
# Epoch: [45]  [ 75/170]  eta: 0:02:23  lr: 0.000098  loss: 0.1109 (0.1085)  loss_classifier: 0.0426 (0.0408)  loss_box_reg: 0.0615 (0.0603)  loss_objectness: 0.0011 (0.0022)  loss_rpn_box_reg: 0.0034 (0.0052)  time: 1.5520  data: 0.0604  max mem: 13074
# Epoch: [45]  [100/170]  eta: 0:01:46  lr: 0.000098  loss: 0.1030 (0.1062)  loss_classifier: 0.0360 (0.0397)  loss_box_reg: 0.0585 (0.0596)  loss_objectness: 0.0014 (0.0021)  loss_rpn_box_reg: 0.0030 (0.0048)  time: 1.5426  data: 0.0583  max mem: 13074
# Epoch: [45]  [125/170]  eta: 0:01:08  lr: 0.000098  loss: 0.0972 (0.1044)  loss_classifier: 0.0331 (0.0392)  loss_box_reg: 0.0511 (0.0585)  loss_objectness: 0.0012 (0.0021)  loss_rpn_box_reg: 0.0033 (0.0046)  time: 1.5798  data: 0.0597  max mem: 13074
# Epoch: [45]  [150/170]  eta: 0:00:30  lr: 0.000098  loss: 0.0890 (0.1039)  loss_classifier: 0.0346 (0.0390)  loss_box_reg: 0.0517 (0.0583)  loss_objectness: 0.0013 (0.0021)  loss_rpn_box_reg: 0.0026 (0.0045)  time: 1.5101  data: 0.0612  max mem: 13074
# Epoch: [45]  [169/170]  eta: 0:00:01  lr: 0.000098  loss: 0.0813 (0.1019)  loss_classifier: 0.0352 (0.0383)  loss_box_reg: 0.0455 (0.0572)  loss_objectness: 0.0006 (0.0021)  loss_rpn_box_reg: 0.0019 (0.0043)  time: 1.4350  data: 0.0613  max mem: 13074
# Epoch: [45] Total time: 0:04:17 (1.5120 s / it)
# mAP:0.508
# 	AP at IoU level [0.50]: 0.739
# 	AP at IoU level [0.55]: 0.739
# 	AP at IoU level [0.60]: 0.723
# 	AP at IoU level [0.65]: 0.692
# 	AP at IoU level [0.70]: 0.681
# 	AP at IoU level [0.75]: 0.566
# 	AP at IoU level [0.80]: 0.529
# 	AP at IoU level [0.85]: 0.332
# 	AP at IoU level [0.90]: 0.078
# 	AP at IoU level [0.95]: 0.000
# Epoch: [46]  [  0/170]  eta: 0:04:30  lr: 0.000098  loss: 0.1241 (0.1241)  loss_classifier: 0.0471 (0.0471)  loss_box_reg: 0.0720 (0.0720)  loss_objectness: 0.0015 (0.0015)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 1.5926  data: 0.0507  max mem: 13074
# Epoch: [46]  [ 25/170]  eta: 0:03:39  lr: 0.000098  loss: 0.0972 (0.1166)  loss_classifier: 0.0369 (0.0416)  loss_box_reg: 0.0562 (0.0668)  loss_objectness: 0.0012 (0.0030)  loss_rpn_box_reg: 0.0034 (0.0052)  time: 1.5364  data: 0.0600  max mem: 13074
# Epoch: [46]  [ 50/170]  eta: 0:03:03  lr: 0.000098  loss: 0.1087 (0.1178)  loss_classifier: 0.0443 (0.0430)  loss_box_reg: 0.0637 (0.0669)  loss_objectness: 0.0009 (0.0029)  loss_rpn_box_reg: 0.0033 (0.0051)  time: 1.5490  data: 0.0603  max mem: 13074
# Epoch: [46]  [ 75/170]  eta: 0:02:25  lr: 0.000098  loss: 0.0659 (0.1079)  loss_classifier: 0.0317 (0.0402)  loss_box_reg: 0.0310 (0.0602)  loss_objectness: 0.0005 (0.0023)  loss_rpn_box_reg: 0.0019 (0.0052)  time: 1.5194  data: 0.0608  max mem: 13074
# Epoch: [46]  [100/170]  eta: 0:01:47  lr: 0.000098  loss: 0.0766 (0.1057)  loss_classifier: 0.0337 (0.0398)  loss_box_reg: 0.0393 (0.0589)  loss_objectness: 0.0009 (0.0022)  loss_rpn_box_reg: 0.0025 (0.0049)  time: 1.5613  data: 0.0613  max mem: 13074
# Epoch: [46]  [125/170]  eta: 0:01:09  lr: 0.000098  loss: 0.0773 (0.1037)  loss_classifier: 0.0296 (0.0392)  loss_box_reg: 0.0419 (0.0580)  loss_objectness: 0.0008 (0.0021)  loss_rpn_box_reg: 0.0016 (0.0045)  time: 1.5914  data: 0.0596  max mem: 13074
# Epoch: [46]  [150/170]  eta: 0:00:30  lr: 0.000098  loss: 0.0800 (0.1035)  loss_classifier: 0.0333 (0.0393)  loss_box_reg: 0.0478 (0.0579)  loss_objectness: 0.0005 (0.0020)  loss_rpn_box_reg: 0.0032 (0.0044)  time: 1.5720  data: 0.0646  max mem: 13074
# Epoch: [46]  [169/170]  eta: 0:00:01  lr: 0.000098  loss: 0.0920 (0.1023)  loss_classifier: 0.0341 (0.0387)  loss_box_reg: 0.0555 (0.0573)  loss_objectness: 0.0007 (0.0020)  loss_rpn_box_reg: 0.0025 (0.0043)  time: 1.4892  data: 0.0627  max mem: 13074
# Epoch: [46] Total time: 0:04:22 (1.5414 s / it)
# mAP:0.508
# 	AP at IoU level [0.50]: 0.739
# 	AP at IoU level [0.55]: 0.739
# 	AP at IoU level [0.60]: 0.723
# 	AP at IoU level [0.65]: 0.704
# 	AP at IoU level [0.70]: 0.681
# 	AP at IoU level [0.75]: 0.566
# 	AP at IoU level [0.80]: 0.529
# 	AP at IoU level [0.85]: 0.333
# 	AP at IoU level [0.90]: 0.069
# 	AP at IoU level [0.95]: 0.000
# Epoch: [47]  [  0/170]  eta: 0:04:31  lr: 0.000098  loss: 0.0626 (0.0626)  loss_classifier: 0.0249 (0.0249)  loss_box_reg: 0.0358 (0.0358)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 1.5946  data: 0.0483  max mem: 13074
# Epoch: [47]  [ 25/170]  eta: 0:03:47  lr: 0.000098  loss: 0.0845 (0.0894)  loss_classifier: 0.0314 (0.0363)  loss_box_reg: 0.0486 (0.0485)  loss_objectness: 0.0006 (0.0012)  loss_rpn_box_reg: 0.0021 (0.0033)  time: 1.5949  data: 0.0620  max mem: 13074
# Epoch: [47]  [ 50/170]  eta: 0:03:07  lr: 0.000098  loss: 0.1003 (0.0955)  loss_classifier: 0.0346 (0.0371)  loss_box_reg: 0.0530 (0.0527)  loss_objectness: 0.0007 (0.0018)  loss_rpn_box_reg: 0.0022 (0.0039)  time: 1.5553  data: 0.0593  max mem: 13074
# Epoch: [47]  [ 75/170]  eta: 0:02:26  lr: 0.000098  loss: 0.1050 (0.1003)  loss_classifier: 0.0354 (0.0386)  loss_box_reg: 0.0691 (0.0560)  loss_objectness: 0.0011 (0.0019)  loss_rpn_box_reg: 0.0021 (0.0039)  time: 1.4606  data: 0.0635  max mem: 13074
# Epoch: [47]  [100/170]  eta: 0:01:47  lr: 0.000098  loss: 0.0991 (0.1037)  loss_classifier: 0.0409 (0.0392)  loss_box_reg: 0.0567 (0.0578)  loss_objectness: 0.0012 (0.0021)  loss_rpn_box_reg: 0.0036 (0.0046)  time: 1.5375  data: 0.0634  max mem: 13074
# Epoch: [47]  [125/170]  eta: 0:01:09  lr: 0.000098  loss: 0.0728 (0.1013)  loss_classifier: 0.0263 (0.0383)  loss_box_reg: 0.0465 (0.0566)  loss_objectness: 0.0006 (0.0021)  loss_rpn_box_reg: 0.0021 (0.0044)  time: 1.5109  data: 0.0598  max mem: 13074
# Epoch: [47]  [150/170]  eta: 0:00:30  lr: 0.000098  loss: 0.0900 (0.1027)  loss_classifier: 0.0358 (0.0388)  loss_box_reg: 0.0576 (0.0573)  loss_objectness: 0.0009 (0.0021)  loss_rpn_box_reg: 0.0031 (0.0045)  time: 1.5261  data: 0.0594  max mem: 13074
# Epoch: [47]  [169/170]  eta: 0:00:01  lr: 0.000098  loss: 0.0975 (0.1023)  loss_classifier: 0.0410 (0.0388)  loss_box_reg: 0.0538 (0.0572)  loss_objectness: 0.0009 (0.0020)  loss_rpn_box_reg: 0.0029 (0.0043)  time: 1.5867  data: 0.0615  max mem: 13074
# Epoch: [47] Total time: 0:04:22 (1.5443 s / it)
# mAP:0.509
# 	AP at IoU level [0.50]: 0.739
# 	AP at IoU level [0.55]: 0.739
# 	AP at IoU level [0.60]: 0.723
# 	AP at IoU level [0.65]: 0.704
# 	AP at IoU level [0.70]: 0.681
# 	AP at IoU level [0.75]: 0.567
# 	AP at IoU level [0.80]: 0.530
# 	AP at IoU level [0.85]: 0.336
# 	AP at IoU level [0.90]: 0.069
# 	AP at IoU level [0.95]: 0.000
# Epoch: [48]  [  0/170]  eta: 0:03:55  lr: 0.000098  loss: 0.0319 (0.0319)  loss_classifier: 0.0126 (0.0126)  loss_box_reg: 0.0191 (0.0191)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0002)  time: 1.3878  data: 0.0484  max mem: 13074
# Epoch: [48]  [ 25/170]  eta: 0:03:41  lr: 0.000098  loss: 0.1016 (0.1090)  loss_classifier: 0.0391 (0.0414)  loss_box_reg: 0.0579 (0.0612)  loss_objectness: 0.0013 (0.0023)  loss_rpn_box_reg: 0.0037 (0.0041)  time: 1.5925  data: 0.0644  max mem: 13074
# Epoch: [48]  [ 50/170]  eta: 0:03:04  lr: 0.000098  loss: 0.0948 (0.1135)  loss_classifier: 0.0409 (0.0434)  loss_box_reg: 0.0544 (0.0637)  loss_objectness: 0.0009 (0.0021)  loss_rpn_box_reg: 0.0029 (0.0042)  time: 1.5738  data: 0.0608  max mem: 13074
# Epoch: [48]  [ 75/170]  eta: 0:02:26  lr: 0.000098  loss: 0.0765 (0.1062)  loss_classifier: 0.0304 (0.0409)  loss_box_reg: 0.0424 (0.0595)  loss_objectness: 0.0003 (0.0018)  loss_rpn_box_reg: 0.0024 (0.0039)  time: 1.5625  data: 0.0604  max mem: 13074
# Epoch: [48]  [100/170]  eta: 0:01:47  lr: 0.000098  loss: 0.0813 (0.1056)  loss_classifier: 0.0313 (0.0400)  loss_box_reg: 0.0463 (0.0588)  loss_objectness: 0.0006 (0.0022)  loss_rpn_box_reg: 0.0021 (0.0046)  time: 1.5126  data: 0.0603  max mem: 13074
# Epoch: [48]  [125/170]  eta: 0:01:09  lr: 0.000098  loss: 0.1161 (0.1057)  loss_classifier: 0.0400 (0.0397)  loss_box_reg: 0.0588 (0.0591)  loss_objectness: 0.0010 (0.0022)  loss_rpn_box_reg: 0.0027 (0.0047)  time: 1.5279  data: 0.0599  max mem: 13074
# Epoch: [48]  [150/170]  eta: 0:00:30  lr: 0.000098  loss: 0.0807 (0.1045)  loss_classifier: 0.0373 (0.0392)  loss_box_reg: 0.0470 (0.0586)  loss_objectness: 0.0006 (0.0022)  loss_rpn_box_reg: 0.0021 (0.0046)  time: 1.5883  data: 0.0628  max mem: 13074
# Epoch: [48]  [169/170]  eta: 0:00:01  lr: 0.000098  loss: 0.0629 (0.1017)  loss_classifier: 0.0289 (0.0384)  loss_box_reg: 0.0343 (0.0569)  loss_objectness: 0.0007 (0.0020)  loss_rpn_box_reg: 0.0015 (0.0043)  time: 1.5772  data: 0.0594  max mem: 13074
# Epoch: [48] Total time: 0:04:23 (1.5483 s / it)
# mAP:0.509
# 	AP at IoU level [0.50]: 0.740
# 	AP at IoU level [0.55]: 0.729
# 	AP at IoU level [0.60]: 0.723
# 	AP at IoU level [0.65]: 0.704
# 	AP at IoU level [0.70]: 0.681
# 	AP at IoU level [0.75]: 0.566
# 	AP at IoU level [0.80]: 0.529
# 	AP at IoU level [0.85]: 0.337
# 	AP at IoU level [0.90]: 0.078
# 	AP at IoU level [0.95]: 0.000
# Epoch: [49]  [  0/170]  eta: 0:04:12  lr: 0.000098  loss: 0.1717 (0.1717)  loss_classifier: 0.0610 (0.0610)  loss_box_reg: 0.1014 (0.1014)  loss_objectness: 0.0019 (0.0019)  loss_rpn_box_reg: 0.0073 (0.0073)  time: 1.4853  data: 0.0662  max mem: 13074
# Epoch: [49]  [ 25/170]  eta: 0:03:38  lr: 0.000098  loss: 0.0945 (0.1037)  loss_classifier: 0.0314 (0.0398)  loss_box_reg: 0.0546 (0.0587)  loss_objectness: 0.0006 (0.0017)  loss_rpn_box_reg: 0.0020 (0.0035)  time: 1.5182  data: 0.0613  max mem: 13074
# Epoch: [49]  [ 50/170]  eta: 0:03:04  lr: 0.000098  loss: 0.1053 (0.1026)  loss_classifier: 0.0413 (0.0399)  loss_box_reg: 0.0588 (0.0575)  loss_objectness: 0.0008 (0.0016)  loss_rpn_box_reg: 0.0034 (0.0035)  time: 1.5661  data: 0.0601  max mem: 13074
# Epoch: [49]  [ 75/170]  eta: 0:02:25  lr: 0.000098  loss: 0.0734 (0.0975)  loss_classifier: 0.0286 (0.0373)  loss_box_reg: 0.0423 (0.0552)  loss_objectness: 0.0008 (0.0016)  loss_rpn_box_reg: 0.0019 (0.0034)  time: 1.4785  data: 0.0582  max mem: 13074
# Epoch: [49]  [100/170]  eta: 0:01:47  lr: 0.000098  loss: 0.0862 (0.0987)  loss_classifier: 0.0323 (0.0375)  loss_box_reg: 0.0420 (0.0559)  loss_objectness: 0.0015 (0.0018)  loss_rpn_box_reg: 0.0024 (0.0035)  time: 1.5508  data: 0.0600  max mem: 13074
# Epoch: [49]  [125/170]  eta: 0:01:08  lr: 0.000098  loss: 0.1081 (0.1015)  loss_classifier: 0.0425 (0.0381)  loss_box_reg: 0.0568 (0.0573)  loss_objectness: 0.0016 (0.0019)  loss_rpn_box_reg: 0.0030 (0.0042)  time: 1.4968  data: 0.0622  max mem: 13074
# Epoch: [49]  [150/170]  eta: 0:00:30  lr: 0.000098  loss: 0.0739 (0.0997)  loss_classifier: 0.0277 (0.0377)  loss_box_reg: 0.0416 (0.0561)  loss_objectness: 0.0005 (0.0019)  loss_rpn_box_reg: 0.0017 (0.0040)  time: 1.6231  data: 0.0619  max mem: 13074
# Epoch: [49]  [169/170]  eta: 0:00:01  lr: 0.000098  loss: 0.1141 (0.1018)  loss_classifier: 0.0378 (0.0380)  loss_box_reg: 0.0657 (0.0573)  loss_objectness: 0.0008 (0.0021)  loss_rpn_box_reg: 0.0033 (0.0043)  time: 1.4856  data: 0.0632  max mem: 13074
# Epoch: [49] Total time: 0:04:21 (1.5363 s / it)
# mAP:0.509
# 	AP at IoU level [0.50]: 0.740
# 	AP at IoU level [0.55]: 0.729
# 	AP at IoU level [0.60]: 0.723
# 	AP at IoU level [0.65]: 0.704
# 	AP at IoU level [0.70]: 0.681
# 	AP at IoU level [0.75]: 0.567
# 	AP at IoU level [0.80]: 0.529
# 	AP at IoU level [0.85]: 0.341
# 	AP at IoU level [0.90]: 0.078
# 	AP at IoU level [0.95]: 0.000

# %% [markdown]
# ### Saving the Model

# %%
from datetime import datetime
# Save model with current date
now = datetime.now()
d = now.strftime("%Y_%b_%d_%Hh_%mm")
PATH = '/content/drive/MyDrive/FaceMaskDetection/model_'+d+'.pt'

# %%
torch.save(model.state_dict(), PATH)

# %% [markdown]
# ### Evaluate and Predict on Test Set

# %%
# Get saved model
model_eval = model.load_state_dict(torch.load(PATH))

# %% [markdown]
# Evaluation:

# %%
# put the model in evaluation mode
model.eval()

# Evaluate the model
evaluate(model, loader_test, device=device)
# Out:
# mAP:0.509
# 	AP at IoU level [0.50]: 0.740
# 	AP at IoU level [0.55]: 0.729
# 	AP at IoU level [0.60]: 0.723
# 	AP at IoU level [0.65]: 0.704
# 	AP at IoU level [0.70]: 0.681
# 	AP at IoU level [0.75]: 0.567
# 	AP at IoU level [0.80]: 0.529
# 	AP at IoU level [0.85]: 0.344
# 	AP at IoU level [0.90]: 0.070
# 	AP at IoU level [0.95]: 0.000
# (0.5086299090447042,
#  [0.7398578761326428,
#   0.7294562232606452,
#   0.7225485974698165,
#   0.7035306301600999,
#   0.68050438388192,
#   0.5665728791553891,
#   0.52942924340238,
#   0.3442539140505943,
#   0.06987622224937409,
#   0.00026912068417985836])

# %% [markdown]
# Test prediction on random image.

# %%
# Make prediction on random image
n = randint(0, dataset_test.len)
img, target = dataset_test[n]
with torch.no_grad():
    prediction = model([img.to(device)])[0]

# Non max suppression to reduce the number of bounding boxes
nms_prediction = apply_nms(prediction, iou_thresh=0.5)
# Remove low score boxes below score_thresh
filtered_prediction = remove_low_score_bb(nms_prediction, score_thresh=0.2)

# Draw bounding boxes
draw_bounding_boxes(img.detach().cpu(), target=target, prediction=filtered_prediction)
# Out:
# 400x225
# <PIL.Image.Image image mode=RGB size=400x225 at 0x7F29DE6ECA90>

# %% [markdown]
# Evaluation from coco tools

# %%
from engine import evaluate as eval 
eval(model, loader_test, device=device)
# Out:
# creating index...
# index created!
# Test:  [0/5]  eta: 0:00:03  model_time: 0.6908 (0.6908)  evaluator_time: 0.0036 (0.0036)  time: 0.7570  data: 0.0600  max mem: 13074
# Test:  [4/5]  eta: 0:00:00  model_time: 0.6614 (0.6637)  evaluator_time: 0.0044 (0.0067)  time: 0.7301  data: 0.0576  max mem: 13074
# Test: Total time: 0:00:03 (0.7304 s / it)
# Averaged stats: model_time: 0.6614 (0.6637)  evaluator_time: 0.0044 (0.0067)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.428
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.696
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.487
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.438
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.420
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.279
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.498
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.433
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.750
